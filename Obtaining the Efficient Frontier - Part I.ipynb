# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
assets = ['PG', '^GSPC']
pf_data = pd.DataFrame()

for a in assets:
    pf_data[a] = wb.DataReader(a, data_source = 'yahoo', start = '2010-1-1')['Adj Close']

# %%
pf_data.tail()
# Out:
#                     PG        ^GSPC
# Date
# 2021-10-04  138.789993  4300.459961
# 2021-10-05  139.330002  4345.720215
# 2021-10-06  141.190002  4363.549805
# 2021-10-07  142.320007  4399.759766
# 2021-10-08  141.729996  4391.339844

# %%
(pf_data / pf_data.iloc[0] * 100).plot(figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
log_returns = np.log(pf_data / pf_data.shift(1))

# %%
log_returns.mean() * 250
# Out:
# PG       0.101842
# ^GSPC    0.115651
# dtype: float64

# %%
log_returns.cov() * 250
# Out:
#              PG     ^GSPC
# PG     0.028617  0.017093
# ^GSPC  0.017093  0.029673

# %%
log_returns.corr()
# Out:
#              PG     ^GSPC
# PG     1.000000  0.586579
# ^GSPC  0.586579  1.000000

# %%
num_assets = len(assets)

# %%
num_assets
# Out:
# 2

# %%
arr = np.random.random(2)
arr
# Out:
# array([0.34652115, 0.30899285])

# %%
arr[0] + arr[1]
# Out:
# 0.6179856908337773

# %%
weights = np.random.random(num_assets)
weights /= np.sum(weights)
weights
# Out:
# array([0.94884039, 0.05115961])

# %%
weights[0] + weights[1]
# Out:
# 1.0
